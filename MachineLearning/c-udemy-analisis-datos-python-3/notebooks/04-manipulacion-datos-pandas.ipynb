# %% [markdown]
# # Lectura de fuentes de datos.
# - 120 años de olimpiadas.
# - https://www.kaggle.com/datasets/heesoo37/120-years-of-olympic-history-athletes-and-results

# %%
# Importando librrerias
import os
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# Consultando arhivos locales en ruta datasets / inputs
path_input_datasets = "../datasets/input/olimpiadas/"
path_output = "../datasets/output/"
os.listdir(path_input_datasets)
#os.mkdir("../datasets/output")
# Out:
# ['athlete_events.csv',
#  'Forbes Richest Athletes 1990-2020.csv',
#  'noc_regions.csv']

# %%
olympics = pd.read_csv(path_input_datasets+'athlete_events.csv')
olympics.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %% [markdown]
# ### Realizando Filtros mascaras, query
# ### Ejemplo para atletas olimpicos peruanos.

# %%
olympics[olympics['NOC'] == 'PER']
# Out:
#             ID                          Name Sex   Age  Height  Weight  Team  \
# 1076       605  Fernando J. Abugattas Aboino   M  20.0   190.0    80.0  Peru
# 1077       606      Roberto Abugattas Aboino   M  21.0   182.0    77.0  Peru
# 1078       606      Roberto Abugattas Aboino   M  25.0   182.0    77.0  Peru
# 1166       649    Fernando Acevedo Portugues   M  22.0   175.0    65.0  Peru
# 1167       649    Fernando Acevedo Portugues   M  26.0   175.0    65.0  Peru
# ...        ...                           ...  ..   ...     ...     ...   ...
# 267568  133860    Miguel Zambrano de la Cruz   M  28.0   182.0   148.0  Peru
# 267640  133894    Yulissa Noelia Zamudio Orl   F  20.0   185.0    75.0  Peru
# 267641  133894    Yulissa Noelia Zamudio Orl   F  24.0   185.0    75.0  Peru
# 268048  134100                 Ramn Zavaleta   M  24.0   181.0    72.0  Peru
# 268270  134227  Carlos Erick Zegarra Presser   M  23.0   202.0   165.0  Peru
#
# ...

# %%
olympics.query('NOC == "PER"')
# Out:
#             ID                          Name Sex   Age  Height  Weight  Team  \
# 1076       605  Fernando J. Abugattas Aboino   M  20.0   190.0    80.0  Peru
# 1077       606      Roberto Abugattas Aboino   M  21.0   182.0    77.0  Peru
# 1078       606      Roberto Abugattas Aboino   M  25.0   182.0    77.0  Peru
# 1166       649    Fernando Acevedo Portugues   M  22.0   175.0    65.0  Peru
# 1167       649    Fernando Acevedo Portugues   M  26.0   175.0    65.0  Peru
# ...        ...                           ...  ..   ...     ...     ...   ...
# 267568  133860    Miguel Zambrano de la Cruz   M  28.0   182.0   148.0  Peru
# 267640  133894    Yulissa Noelia Zamudio Orl   F  20.0   185.0    75.0  Peru
# 267641  133894    Yulissa Noelia Zamudio Orl   F  24.0   185.0    75.0  Peru
# 268048  134100                 Ramn Zavaleta   M  24.0   181.0    72.0  Peru
# 268270  134227  Carlos Erick Zegarra Presser   M  23.0   202.0   165.0  Peru
#
# ...

# %%
# Realizando filtros conjuntos, Ejemplo los medallistas de Seul 88.
olympics[(olympics['NOC'] == 'PER') & 
         (olympics['Sport'] == 'Volleyball') & 
         (olympics['Year'] == 1988) & 
         (olympics['Medal'] == 'Silver')]
# Out:
#             ID                                             Name Sex   Age  \
# 37847    19448                     Luisa Haydee Cervera Cevedon   F  24.0
# 51127    26272                           Alejandra de la Guerra   F  20.0
# 66098    33819                            Denisse Fajardo Garca   F  24.0
# 75122    38118                                  Miriam Gallardo   F  20.0
# 76249    38692                         Rosa Gisella Garca Rivas   F  24.0
# 94622    47883                             Sonia Isabel Heredia   F  24.0
# 98804    50004                          Katherine "Kathy" Horny   F  18.0
# 147339   73946                         Natalia Mara Mlaga Dibos   F  24.0
# 185611   93317  Gabriela Lourdes "Gaby" Prez del Solar Cuculiza   F  20.0
# 234999  117844                   Cecilia Roxana Tait Villacorta   F  26.0
# 242031  121233                                   Gina Torrealva   F  26.0
# 246625  123484                  Cenaida Cebastiana Uribe Medina   F  22.0
#
# ...

# %%
# Realizando filtros conjuntos, Ejemplo los medallistas de Seul 88 con la funcion query.
olympics.query('(NOC == "PER") & (Sport == "Volleyball") & (Year == 1988) & (Medal == "Silver")')
# Out:
#             ID                                             Name Sex   Age  \
# 37847    19448                     Luisa Haydee Cervera Cevedon   F  24.0
# 51127    26272                           Alejandra de la Guerra   F  20.0
# 66098    33819                            Denisse Fajardo Garca   F  24.0
# 75122    38118                                  Miriam Gallardo   F  20.0
# 76249    38692                         Rosa Gisella Garca Rivas   F  24.0
# 94622    47883                             Sonia Isabel Heredia   F  24.0
# 98804    50004                          Katherine "Kathy" Horny   F  18.0
# 147339   73946                         Natalia Mara Mlaga Dibos   F  24.0
# 185611   93317  Gabriela Lourdes "Gaby" Prez del Solar Cuculiza   F  20.0
# 234999  117844                   Cecilia Roxana Tait Villacorta   F  26.0
# 242031  121233                                   Gina Torrealva   F  26.0
# 246625  123484                  Cenaida Cebastiana Uribe Medina   F  22.0
#
# ...

# %%
# Filtros con comparaciones.
olympics[olympics['Age'] < 20].head()
# Out:
#      ID                                Name Sex   Age  Height  Weight  \
# 26    8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 27    8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 87   26        Agnes Erika Aanonsen (-Eyde)   F  17.0   169.0    65.0
# 167  69                   Tamara Abalde Daz   F  19.0   185.0    72.0
# 203  96   Carlos Rodolfo Abaunza Balladares   M  18.0   168.0    60.0
#
#             Team  NOC        Games  Year  Season         City       Sport  \
# 26   Netherlands  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
# 27   Netherlands  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
# 87        Norway  NOR  1984 Winter  1984  Winter     Sarajevo        Luge
# 167        Spain  ESP  2008 Summer  2008  Summer      Beijing  Basketball
# 203    Nicaragua  NCA  2004 Summer  2004  Summer       Athina   Athletics
#
#                                       Event Medal
# ...

# %%
# Filtro comparando campos peso mayor que la altura.
olympics.query('Weight > Height')
# Out:
#           ID               Name Sex   Age  Height  Weight  Team  NOC  \
# 23155  12177  Ricardo Blas, Jr.   M  21.0   183.0   214.0  Guam  GUM
# 23156  12177  Ricardo Blas, Jr.   M  25.0   183.0   214.0  Guam  GUM
#
#              Games  Year  Season     City Sport                   Event Medal
# 23155  2008 Summer  2008  Summer  Beijing  Judo  Judo Men's Heavyweight   NaN
# 23156  2012 Summer  2012  Summer   London  Judo  Judo Men's Heavyweight   NaN

# %%
# Filtros con listas.
olympics['Sport'].unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %%
deportes = ['Tennis','Table Tennis']

# %%
olympics[olympics['Sport'].isin(deportes)]
# Out:
#             ID                                  Name Sex   Age  Height  \
# 184         82                Enrique Abaroa Martnez   M  26.0   183.0
# 498        277                    Shaimaa Abdul Aziz   F  19.0   160.0
# 499        277                    Shaimaa Abdul Aziz   F  19.0   160.0
# 500        277                    Shaimaa Abdul Aziz   F  27.0   160.0
# 582        334              Abubakar Sadiq Abdullahi   M  28.0     NaN
# ...        ...                                   ...  ..   ...     ...
# 270980  135502  Nataliya Maratovna "Natasha" Zvereva   F  29.0   172.0
# 270986  135508              Vera Igorevna Zvonaryova   F  23.0   172.0
# 270987  135508              Vera Igorevna Zvonaryova   F  23.0   172.0
# 270988  135508              Vera Igorevna Zvonaryova   F  27.0   172.0
# 271020  135526                          Dniel Zwickl   M  27.0   178.0
#
#         Weight      Team  NOC        Games  Year  Season     City  \
# ...

# %%
olympics[olympics['Sport'].isin(deportes) & (olympics['City'] == 'Sydney')]
# Out:
#             ID                                  Name Sex   Age  Height  \
# 184         82                Enrique Abaroa Martnez   M  26.0   183.0
# 498        277                    Shaimaa Abdul Aziz   F  19.0   160.0
# 499        277                    Shaimaa Abdul Aziz   F  19.0   160.0
# 1457       812                     David Dixie Adams   M  30.0   188.0
# 2022      1116      Eldijana Dana Aganovi (-Bentsen)   F  28.0   173.0
# ...        ...                                   ...  ..   ...     ...
# 269911  135043                         Nenad Zimonji   M  24.0   190.0
# 270775  135417                 Fabiola Zuluaga Amado   F  21.0   171.0
# 270776  135417                 Fabiola Zuluaga Amado   F  21.0   171.0
# 270979  135502  Nataliya Maratovna "Natasha" Zvereva   F  29.0   172.0
# 270980  135502  Nataliya Maratovna "Natasha" Zvereva   F  29.0   172.0
#
#         Weight                   Team  NOC        Games  Year  Season    City  \
# ...

# %%
# Filtros isnull 
olympics[olympics['Medal'].isnull()]
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                Team  NOC        Games  Year  Season            City  \
# 0             China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
# Filtros notnull 
# opcion 1 negando la condicion con el comando ~
# olympics[ ~ olympics['Medal'].isnull()]
# opcion 2 con el comando pandas notnull
# Filtros isnull 
olympics[olympics['Medal'].notnull()]
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 37          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 38          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 40          16             Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 41          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# ...        ...                                  ...  ..   ...     ...     ...
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F  25.0   168.0    80.0
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271082  135554                         Bogusaw Zych   M  28.0   182.0    82.0
# 271102  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 271103  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
#
# ...

# %%
# Realizando filtros Negativos.
olympics[olympics['NOC'] != 'CHN']
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# ...

# %%
# Realizando filtros negativos con query.
olympics.query('NOC != "CHN"')
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# ...

# %%
# Realizando filtros con String.
olympics_rou = olympics[olympics['NOC'] == 'ROU']

# %%
# Realizando filtro por el innicio del nombre de la atleta Nadia.
olympics_rou[olympics_rou['Name'].str.startswith('Nadia')]
# Out:
#           ID                           Name Sex   Age  Height  Weight  \
# 43773  22570  Nadia Elena Comneci (-Conner)   F  14.0   162.0    45.0
# 43774  22570  Nadia Elena Comneci (-Conner)   F  14.0   162.0    45.0
# 43775  22570  Nadia Elena Comneci (-Conner)   F  14.0   162.0    45.0
# 43776  22570  Nadia Elena Comneci (-Conner)   F  14.0   162.0    45.0
# 43777  22570  Nadia Elena Comneci (-Conner)   F  14.0   162.0    45.0
# 43778  22570  Nadia Elena Comneci (-Conner)   F  14.0   162.0    45.0
# 43779  22570  Nadia Elena Comneci (-Conner)   F  18.0   162.0    45.0
# 43780  22570  Nadia Elena Comneci (-Conner)   F  18.0   162.0    45.0
# 43781  22570  Nadia Elena Comneci (-Conner)   F  18.0   162.0    45.0
# 43782  22570  Nadia Elena Comneci (-Conner)   F  18.0   162.0    45.0
# 43783  22570  Nadia Elena Comneci (-Conner)   F  18.0   162.0    45.0
# 43784  22570  Nadia Elena Comneci (-Conner)   F  18.0   162.0    45.0
#
# ...

# %%
# Realizando filtro por el final del apellido con las letras ci.
olympics_rou[olympics_rou['Name'].str.endswith('ci')]
# Out:
#             ID             Name Sex   Age  Height  Weight     Team  NOC  \
# 28823    14927    Virgil Brenci   M  25.0   173.0    71.0  Romania  ROU
# 28824    14927    Virgil Brenci   M  25.0   173.0    71.0  Romania  ROU
# 28825    14927    Virgil Brenci   M  25.0   173.0    71.0  Romania  ROU
# 31269    16072     Antoniu Buci   M  18.0   161.0    62.0  Romania  ROU
# 42987    22169   Alexandru Coci   M  22.0   174.0    70.0  Romania  ROU
# ...        ...              ...  ..   ...     ...     ...      ...  ...
# 222795  111910  Eveline Slavici   F  19.0     NaN     NaN  Romania  ROU
# 224311  112674    Andrei Socaci   M  18.0   164.0    75.0  Romania  ROU
# 224312  112674    Andrei Socaci   M  22.0   164.0    75.0  Romania  ROU
# 240444  120489   Manuela Trneci   F  23.0   172.0    82.0  Romania  ROU
# 242445  121429   Liviu Totolici   M  27.0     NaN     NaN  Romania  ROU
#
#               Games  Year  Season         City          Sport  \
# ...

# %% [markdown]
# #### Ejercicios. Busqueda del atleta usaint Bolt, busqueda basada en patrones.

# %%
# 72. 4.4.2 Ejercicios. Busqueda del atleta usaint Bolt, busqueda basada en patrones.
olympics[olympics['Name'].str.startswith('Usain')]
# Out:
#           ID                Name Sex   Age  Height  Weight     Team  NOC  \
# 24876  13029  Usain St. Leo Bolt   M  17.0   196.0    95.0  Jamaica  JAM
# 24877  13029  Usain St. Leo Bolt   M  21.0   196.0    95.0  Jamaica  JAM
# 24878  13029  Usain St. Leo Bolt   M  21.0   196.0    95.0  Jamaica  JAM
# 24879  13029  Usain St. Leo Bolt   M  21.0   196.0    95.0  Jamaica  JAM
# 24880  13029  Usain St. Leo Bolt   M  25.0   196.0    95.0  Jamaica  JAM
# 24881  13029  Usain St. Leo Bolt   M  25.0   196.0    95.0  Jamaica  JAM
# 24882  13029  Usain St. Leo Bolt   M  25.0   196.0    95.0  Jamaica  JAM
# 24883  13029  Usain St. Leo Bolt   M  29.0   196.0    95.0  Jamaica  JAM
# 24884  13029  Usain St. Leo Bolt   M  29.0   196.0    95.0  Jamaica  JAM
# 24885  13029  Usain St. Leo Bolt   M  29.0   196.0    95.0  Jamaica  JAM
#
#              Games  Year  Season            City      Sport  \
# 24876  2004 Summer  2004  Summer          Athina  Athletics
# ...

# %%
# 72. 4.4.2 Ejercicios. Busqueda del atleta usaint Bolt, busqueda basada en patrones.
olympics[olympics['Name'].str.contains('Phelps') & (olympics['NOC'] == 'USA') & (olympics['Sport'] == 'Swimming')]
# Out:
#            ID                     Name Sex   Age  Height  Weight  \
# 187887  94406  Michael Fred Phelps, II   M  15.0   193.0    91.0
# 187888  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187889  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187890  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187891  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187892  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187893  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187894  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187895  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187896  94406  Michael Fred Phelps, II   M  23.0   193.0    91.0
# 187897  94406  Michael Fred Phelps, II   M  23.0   193.0    91.0
# 187898  94406  Michael Fred Phelps, II   M  23.0   193.0    91.0
# 187899  94406  Michael Fred Phelps, II   M  23.0   193.0    91.0
# ...

# %%
# 73. Ejercicio Atetas que le ganaron una competencia a Michael Fred Phelps, II
olympics_phelps = olympics[olympics['Name'].str.contains('Phelps') & (olympics['NOC'] == 'USA') & (olympics['Sport'] == 'Swimming')]

# %%
# 74. Solucion Ejercicio Ganadores Atetas que le ganaron una competencia a Michael Fred Phelps, II
olympics_phelps = olympics_phelps.query('Medal != "Gold"')
olympics_phelps
# Out:
#            ID                     Name Sex   Age  Height  Weight  \
# 187887  94406  Michael Fred Phelps, II   M  15.0   193.0    91.0
# 187888  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187889  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187904  94406  Michael Fred Phelps, II   M  27.0   193.0    91.0
# 187907  94406  Michael Fred Phelps, II   M  27.0   193.0    91.0
# 187909  94406  Michael Fred Phelps, II   M  27.0   193.0    91.0
# 187913  94406  Michael Fred Phelps, II   M  31.0   193.0    91.0
#
#                  Team  NOC        Games  Year  Season            City  \
# 187887  United States  USA  2000 Summer  2000  Summer          Sydney
# 187888  United States  USA  2004 Summer  2004  Summer          Athina
# 187889  United States  USA  2004 Summer  2004  Summer          Athina
# 187904  United States  USA  2012 Summer  2012  Summer          London
# 187907  United States  USA  2012 Summer  2012  Summer          London
# ...

# %%
# 74. Creando nueva columna con los eventos.
olympics_phelps['Event_game'] = olympics_phelps['Games'] + ' - ' + olympics_phelps['Event']

# %%
olympics_phelps.head()
# Out:
#            ID                     Name Sex   Age  Height  Weight  \
# 187887  94406  Michael Fred Phelps, II   M  15.0   193.0    91.0
# 187888  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187889  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187904  94406  Michael Fred Phelps, II   M  27.0   193.0    91.0
# 187907  94406  Michael Fred Phelps, II   M  27.0   193.0    91.0
#
#                  Team  NOC        Games  Year  Season    City     Sport  \
# 187887  United States  USA  2000 Summer  2000  Summer  Sydney  Swimming
# 187888  United States  USA  2004 Summer  2004  Summer  Athina  Swimming
# 187889  United States  USA  2004 Summer  2004  Summer  Athina  Swimming
# 187904  United States  USA  2012 Summer  2012  Summer  London  Swimming
# 187907  United States  USA  2012 Summer  2012  Summer  London  Swimming
#
#                                                 Event   Medal  \
# 187887            Swimming Men's 200 metres Butterfly     NaN
# ...

# %%
# 74. se crea la columna en el dataframe Original.
olympics['Event_game'] = olympics['Games'] + ' - ' + olympics['Event']

# %%
# Se realiza una busqueda por listas.
events_phelps = list(olympics_phelps['Event_game'])

# %%
events_phelps
# Out:
# ["2000 Summer - Swimming Men's 200 metres Butterfly",
#  "2004 Summer - Swimming Men's 200 metres Freestyle",
#  "2004 Summer - Swimming Men's 4 x 100 metres Freestyle Relay",
#  "2012 Summer - Swimming Men's 4 x 100 metres Freestyle Relay",
#  "2012 Summer - Swimming Men's 200 metres Butterfly",
#  "2012 Summer - Swimming Men's 400 metres Individual Medley",
#  "2016 Summer - Swimming Men's 100 metres Butterfly"]

# %%
# 74. Busqueda de eventos por la lista.
olympics[olympics['Event_game'].isin(events_phelps) & (olympics['Medal'] == 'Gold')]
# Out:
#             ID                                   Name Sex   Age  Height  \
# 2111      1173                          Yannick Agnel   M  20.0   202.0
# 20241    10674        Alain Andr Louis Edmond Bernard   M  29.0   196.0
# 68360    34914                           Lyndon Ferns   M  20.0   187.0
# 79554    40403  Fabien Pierre Aurlien Dominique Gilot   M  28.0   193.0
# 134048   67496              Chad Guy Bertrand le Clos   M  20.0   190.0
# 135680   68271                          Clment Lefert   M  24.0   185.0
# 137501   69117                 Amaury Raymond Leveaux   M  26.0   202.0
# 141436   70965                     Ryan Steven Lochte   M  27.0   188.0
# 147417   73989            Thomas Andrew "Tom" Malchow   M  24.0   198.0
# 169198   85056                          Ryk Neethling   M  26.0   196.0
# 213783  107355                   Roland Mark Schoeman   M  24.0   190.0
# 213955  107436                 Joseph Isaac Schooling   M  21.0   184.0
# ...

# %%
# 75. Cambiando el indice por la columna ID.
olympics = olympics.set_index('ID')

# %%
olympics.head(10)
# Out:
#                         Name Sex   Age  Height  Weight            Team  NOC  \
# ID
# 1                  A Dijiang   M  24.0   180.0    80.0           China  CHN
# 2                   A Lamusi   M  23.0   170.0    60.0           China  CHN
# 3        Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark  DEN
# 4       Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 5   Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands  NED
# 5   Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands  NED
# 5   Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands  NED
# 5   Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands  NED
# 5   Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands  NED
# 5   Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands  NED
#
#           Games  Year  Season         City          Sport  \
# ID
# 1   1992 Summer  1992  Summer    Barcelona     Basketball
# ...

# %%
# Recuperando todos los valores asociados al indice 5 con loc.
olympics.loc[5]
# Out:
#                         Name Sex   Age  Height  Weight         Team  NOC  \
# ID
# 5   Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5   Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5   Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 5   Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 5   Christine Jacoba Aaftink   F  27.0   185.0    82.0  Netherlands  NED
# 5   Christine Jacoba Aaftink   F  27.0   185.0    82.0  Netherlands  NED
#
#           Games  Year  Season         City          Sport  \
# ID
# 5   1988 Winter  1988  Winter      Calgary  Speed Skating
# 5   1988 Winter  1988  Winter      Calgary  Speed Skating
# 5   1992 Winter  1992  Winter  Albertville  Speed Skating
# 5   1992 Winter  1992  Winter  Albertville  Speed Skating
# 5   1994 Winter  1994  Winter  Lillehammer  Speed Skating
# 5   1994 Winter  1994  Winter  Lillehammer  Speed Skating
#
# ...

# %%
# Recuperando la posicion 5 con el metodo iloc.
olympics.iloc[5]
# Out:
# Name                                  Christine Jacoba Aaftink
# Sex                                                          F
# Age                                                       21.0
# Height                                                   185.0
# Weight                                                    82.0
# Team                                               Netherlands
# NOC                                                        NED
# Games                                              1988 Winter
# Year                                                      1988
# Season                                                  Winter
# City                                                   Calgary
# Sport                                            Speed Skating
# Event                       Speed Skating Women's 1,000 metres
# Medal                                                      NaN
# Event_game    1988 Winter - Speed Skating Women's 1,000 metres
# Name: 5, dtype: object

# %%
# Filtrando registros por filas y columnas con loc[f, c]
olympics.loc[5, ['Name', 'Sex', 'Games']]
# Out:
#                         Name Sex        Games
# ID
# 5   Christine Jacoba Aaftink   F  1988 Winter
# 5   Christine Jacoba Aaftink   F  1988 Winter
# 5   Christine Jacoba Aaftink   F  1992 Winter
# 5   Christine Jacoba Aaftink   F  1992 Winter
# 5   Christine Jacoba Aaftink   F  1994 Winter
# 5   Christine Jacoba Aaftink   F  1994 Winter

# %%
# Filtrando registros por filas y columnas definiendo un origen hasta un final con loc[f, c]
olympics.loc[20:25 , 'Name': 'Team']
# Out:
#                          Name Sex   Age  Height  Weight     Team
# ID
# 20         Kjetil Andr Aamodt   M  20.0   176.0    85.0   Norway
# 20         Kjetil Andr Aamodt   M  20.0   176.0    85.0   Norway
# 20         Kjetil Andr Aamodt   M  20.0   176.0    85.0   Norway
# 20         Kjetil Andr Aamodt   M  20.0   176.0    85.0   Norway
# 20         Kjetil Andr Aamodt   M  22.0   176.0    85.0   Norway
# 20         Kjetil Andr Aamodt   M  22.0   176.0    85.0   Norway
# 20         Kjetil Andr Aamodt   M  22.0   176.0    85.0   Norway
# 20         Kjetil Andr Aamodt   M  22.0   176.0    85.0   Norway
# 20         Kjetil Andr Aamodt   M  22.0   176.0    85.0   Norway
# 20         Kjetil Andr Aamodt   M  26.0   176.0    85.0   Norway
# 20         Kjetil Andr Aamodt   M  26.0   176.0    85.0   Norway
# 20         Kjetil Andr Aamodt   M  26.0   176.0    85.0   Norway
# 20         Kjetil Andr Aamodt   M  26.0   176.0    85.0   Norway
# ...

# %%
# Cambiando nombres de las columnas.
olympics2 = olympics.get(['Name', 'Sex', 'Age'])

# %%
olympics2.head()
# Out:
#                         Name Sex   Age
# ID
# 1                  A Dijiang   M  24.0
# 2                   A Lamusi   M  23.0
# 3        Gunnar Nielsen Aaby   M  24.0
# 4       Edgar Lindenau Aabye   M  34.0
# 5   Christine Jacoba Aaftink   F  21.0

# %%
# Se modifican los nombres de las columnas a español.
olympics2.columns = ['Nome', 'Sexo', 'Edad']

# %%
olympics2.head()
# Out:
#                         Nome Sexo  Edad
# ID
# 1                  A Dijiang    M  24.0
# 2                   A Lamusi    M  23.0
# 3        Gunnar Nielsen Aaby    M  24.0
# 4       Edgar Lindenau Aabye    M  34.0
# 5   Christine Jacoba Aaftink    F  21.0

# %%
# Modificar el nombre de una sola columna con el metodo rename.
olympics2 = olympics2.rename(columns= {'Nome': 'Nombre'})

# %%
olympics2.head()
# Out:
#                       Nombre Sexo  Edad
# ID
# 1                  A Dijiang    M  24.0
# 2                   A Lamusi    M  23.0
# 3        Gunnar Nielsen Aaby    M  24.0
# 4       Edgar Lindenau Aabye    M  34.0
# 5   Christine Jacoba Aaftink    F  21.0

# %%
# Cambiando el nombre de las columnas a minuscula.
olympics2.columns = [col.lower() for col in olympics2.columns]

# %%
olympics2.head()
# Out:
#                       nombre sexo  edad
# ID
# 1                  A Dijiang    M  24.0
# 2                   A Lamusi    M  23.0
# 3        Gunnar Nielsen Aaby    M  24.0
# 4       Edgar Lindenau Aabye    M  34.0
# 5   Christine Jacoba Aaftink    F  21.0

# %%
# Consultando las columnas.
olympics2.columns
# Out:
# Index(['nombre', 'sexo', 'edad'], dtype='object')

# %%
# Modificando el nombre de las columnas a MAYUSCULA usando el indice.
olympics2.columns = olympics2.columns.str.upper()

# %%
olympics2.head()
# Out:
#                       NOMBRE SEXO  EDAD
# ID
# 1                  A Dijiang    M  24.0
# 2                   A Lamusi    M  23.0
# 3        Gunnar Nielsen Aaby    M  24.0
# 4       Edgar Lindenau Aabye    M  34.0
# 5   Christine Jacoba Aaftink    F  21.0

# %%
# Modificando el nombre de las columnas con la primera MAYUSCULA usando CAPITALICE y el indice.
olympics2.columns = olympics2.columns.str.capitalize()

# %%
olympics2.head()
# Out:
#                       Nombre Sexo  Edad
# ID
# 1                  A Dijiang    M  24.0
# 2                   A Lamusi    M  23.0
# 3        Gunnar Nielsen Aaby    M  24.0
# 4       Edgar Lindenau Aabye    M  34.0
# 5   Christine Jacoba Aaftink    F  21.0

# %%
# Modificando el nombre de las columnas a MAYUSCULA usando el indice.
olympics2.columns = olympics2.columns.str.lower()

# %%
olympics2.head()
# Out:
#                       nombre sexo  edad
# ID
# 1                  A Dijiang    M  24.0
# 2                   A Lamusi    M  23.0
# 3        Gunnar Nielsen Aaby    M  24.0
# 4       Edgar Lindenau Aabye    M  34.0
# 5   Christine Jacoba Aaftink    F  21.0

# %% [markdown]
# ### Transformaciones entre columnas.

# %%
# Convirtiendo altura en metros.

olympics['Height'] / 100
# Out:
# ID
# 1         1.80
# 2         1.70
# 3          NaN
# 4          NaN
# 5         1.85
#           ...
# 135569    1.79
# 135570    1.76
# 135570    1.76
# 135571    1.85
# 135571    1.85
# Name: Height, Length: 271116, dtype: float64

# %%
# Generando el Indice de Masa corporal en una nueva columna BMI.
olympics['BMI'] = olympics['Weight'] / (olympics['Height'] / 100) ** 2

# %%
olympics['BMI'].describe()
# Out:
# count    206853.000000
# mean         22.784520
# std           2.912067
# min           8.360954
# 25%          20.957171
# 50%          22.530864
# 75%          24.212293
# max          63.901580
# Name: BMI, dtype: float64

# %%
# Consultando los atletas con indice de masa corporal BMI mayor a 60.
olympics[olympics['BMI'] > 60]
# Out:
#                     Name Sex   Age  Height  Weight  Team  NOC        Games  \
# ID
# 12177  Ricardo Blas, Jr.   M  21.0   183.0   214.0  Guam  GUM  2008 Summer
# 12177  Ricardo Blas, Jr.   M  25.0   183.0   214.0  Guam  GUM  2012 Summer
#
#        Year  Season     City Sport                   Event Medal  \
# ID
# 12177  2008  Summer  Beijing  Judo  Judo Men's Heavyweight   NaN
# 12177  2012  Summer   London  Judo  Judo Men's Heavyweight   NaN
#
#                                  Event_game       BMI
# ID
# 12177  2008 Summer - Judo Men's Heavyweight  63.90158
# 12177  2012 Summer - Judo Men's Heavyweight  63.90158

# %%
sb.histplot(olympics['BMI'], bins=20)
# Out:
# <Axes: xlabel='BMI', ylabel='Count'>

# %%
# Agregando columna Full Name sumando columnas.
olympics['Olympic'] = olympics['City'] + ' ' + olympics['Year'].astype('str')

# %%
olympics.head()
# Out:
#                         Name Sex   Age  Height  Weight            Team  NOC  \
# ID
# 1                  A Dijiang   M  24.0   180.0    80.0           China  CHN
# 2                   A Lamusi   M  23.0   170.0    60.0           China  CHN
# 3        Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark  DEN
# 4       Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 5   Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands  NED
#
#           Games  Year  Season       City          Sport  \
# ID
# 1   1992 Summer  1992  Summer  Barcelona     Basketball
# 2   2012 Summer  2012  Summer     London           Judo
# 3   1920 Summer  1920  Summer  Antwerpen       Football
# 4   1900 Summer  1900  Summer      Paris     Tug-Of-War
# 5   1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                                Event Medal  \
# ID
# 1        Basketball Men's Basketball   NaN
# 2       Judo Men's Extra-Lightweight   NaN
# ...

# %%
# Modificando valores existentes en las columnas con el metodo MAP.
olympics['Sex_numeric'] = olympics['Sex'].map({'M':1, 'F':0})

# %%
olympics.loc[:10,['Sex','Sex_numeric']]
# Out:
#    Sex  Sex_numeric
# ID
# 1    M            1
# 2    M            1
# 3    M            1
# 4    M            1
# 5    F            0
# 5    F            0
# 5    F            0
# 5    F            0
# 5    F            0
# 5    F            0
# 6    M            1
# 6    M            1
# 6    M            1
# 6    M            1
# 6    M            1
# 6    M            1
# 6    M            1
# 6    M            1
# 7    M            1
# 7    M            1
# 7    M            1
# 7    M            1
# 7    M            1
# 7    M            1
# 7    M            1
# 7    M            1
# 8    F            0
# 8    F            0
# 9    M            1
# 10   M            1

# %%
# Creando nueva columna que valida si el atleta era mayor de edad.
def es_adulto(edad):
    if edad >= 18:
        return 1
    else:
        return 0

# %%
# Creando nueva columna que valida si el atleta era mayor de edad. con la funcion creada adulto.
olympics['Adult'] = olympics['Age'].apply(es_adulto)

# %%
olympics.head()
# Out:
#                         Name Sex   Age  Height  Weight            Team  NOC  \
# ID
# 1                  A Dijiang   M  24.0   180.0    80.0           China  CHN
# 2                   A Lamusi   M  23.0   170.0    60.0           China  CHN
# 3        Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark  DEN
# 4       Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 5   Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands  NED
#
#           Games  Year  Season       City          Sport  \
# ID
# 1   1992 Summer  1992  Summer  Barcelona     Basketball
# 2   2012 Summer  2012  Summer     London           Judo
# 3   1920 Summer  1920  Summer  Antwerpen       Football
# 4   1900 Summer  1900  Summer      Paris     Tug-Of-War
# 5   1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                                Event Medal  \
# ID
# 1        Basketball Men's Basketball   NaN
# 2       Judo Men's Extra-Lightweight   NaN
# ...

# %%
olympics.query('Age < 19').head()
# Out:
#                                   Name Sex   Age  Height  Weight         Team  \
# ID
# 8   Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN  Netherlands
# 8   Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN  Netherlands
# 26        Agnes Erika Aanonsen (-Eyde)   F  17.0   169.0    65.0       Norway
# 96   Carlos Rodolfo Abaunza Balladares   M  18.0   168.0    60.0    Nicaragua
# 97              Carlos Alberto Abaunza   M  16.0   180.0    70.0    Nicaragua
#
#     NOC        Games  Year  Season         City      Sport  \
# ID
# 8   NED  1932 Summer  1932  Summer  Los Angeles  Athletics
# 8   NED  1932 Summer  1932  Summer  Los Angeles  Athletics
# 26  NOR  1984 Winter  1984  Winter     Sarajevo       Luge
# 96  NCA  2004 Summer  2004  Summer       Athina  Athletics
# 97  NCA  1976 Summer  1976  Summer     Montreal  Athletics
#
#                                      Event Medal  \
# ID
# 8             Athletics Women's 100 metres   NaN
# ...

# %%
# aplicando la funcion lambda para calcular altura en metros.
olympics['Height_m'] = olympics['Height'].apply(lambda x: x / 100)

# %%
olympics.head()
# Out:
#                         Name Sex   Age  Height  Weight            Team  NOC  \
# ID
# 1                  A Dijiang   M  24.0   180.0    80.0           China  CHN
# 2                   A Lamusi   M  23.0   170.0    60.0           China  CHN
# 3        Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark  DEN
# 4       Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 5   Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands  NED
#
#           Games  Year  Season       City          Sport  \
# ID
# 1   1992 Summer  1992  Summer  Barcelona     Basketball
# 2   2012 Summer  2012  Summer     London           Judo
# 3   1920 Summer  1920  Summer  Antwerpen       Football
# 4   1900 Summer  1900  Summer      Paris     Tug-Of-War
# 5   1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                                Event Medal  \
# ID
# 1        Basketball Men's Basketball   NaN
# 2       Judo Men's Extra-Lightweight   NaN
# ...

# %%
# Obteniendo las variables de tipo float.
olympics_float = olympics.select_dtypes('float')

# %%
# Aplicando funciones existentes a todo un dataframe. MAX.
olympics_float.apply(max)
# Out:
# Age          97.00000
# Height      226.00000
# Weight      214.00000
# BMI          63.90158
# Height_m      2.26000
# dtype: float64

# %%
# Aplicando el valor maximo a las columnas
olympics_float.apply(max, axis = 0)
# Out:
# Age          97.00000
# Height      226.00000
# Weight      214.00000
# BMI          63.90158
# Height_m      2.26000
# dtype: float64

# %%
# Aplicando el valor maximo a las filas
olympics_float.apply(max, axis = 1)
# Out:
# ID
# 1         180.0
# 2         170.0
# 3          24.0
# 4          34.0
# 5         185.0
#           ...
# 135569    179.0
# 135570    176.0
# 135570    176.0
# 135571    185.0
# 135571    185.0
# Length: 271116, dtype: float64

# %%
# funcion que comparte la ubicacion de donde esta el valor maximo con numpy y argmax.
olympics_float.apply(np.argmax)
# Out:
# Age         257054
# Height      265040
# Weight       23155
# BMI          23155
# Height_m    265040
# dtype: int64

# %%
# Busando la posicion del punto anterior.
olympics_float.iloc[265040]
# Out:
# Age          20.000000
# Height      226.000000
# Weight      141.000000
# BMI          27.605921
# Height_m      2.260000
# Name: 132627, dtype: float64

# %% [markdown]
# ### Ordenamientos

# %%
# Encontrar el medallista de oro mas Joven
olympics = pd.read_csv(path_input_datasets+'athlete_events.csv')
olympics_gold = olympics[olympics['Medal'] == 'Gold']
olympics_gold.sort_values(by='Age').head(10)
# Out:
#             ID                                      Name Sex   Age  Height  \
# 268602  134381                               Klaus Zerta   M  13.0   165.0
# 52010    26731        Donna Elizabeth de Varona (-Pinto)   F  13.0   168.0
# 119277   60384                                Kim Yun-Mi   F  13.0   160.0
# 27207    14142                             Hans Bourquin   M  13.0     NaN
# 73581    37398                                Fu Mingxia   F  13.0   160.0
# 78544    39866              Marjorie Gestring (-Redlick)   F  13.0     NaN
# 200704  100797             Aileen Muriel Riggin (-Soule)   F  13.0   142.0
# 69216    35292  Mariya Yevgenyevna Filatova (-Kurbatova)   F  14.0   136.0
# 163440   82042              Sandra Anne Morgan (-Beavis)   F  14.0   167.0
# 172293   86555           Carola Nitschke (-Beraktschjan)   F  14.0   172.0
#
#         Weight           Team  NOC        Games  Year  Season         City  \
# ...

# %%
# Definiendo un segundo parametro para el ordenamiento.
olympics_gold.sort_values(by= ['Age', 'NOC']).head(10)
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 73581    37398                          Fu Mingxia   F  13.0   160.0    48.0
# 268602  134381                         Klaus Zerta   M  13.0   165.0    48.0
# 119277   60384                          Kim Yun-Mi   F  13.0   160.0    48.0
# 27207    14142                       Hans Bourquin   M  13.0     NaN     NaN
# 52010    26731  Donna Elizabeth de Varona (-Pinto)   F  13.0   168.0    61.0
# 78544    39866        Marjorie Gestring (-Redlick)   F  13.0     NaN     NaN
# 200704  100797       Aileen Muriel Riggin (-Soule)   F  13.0   142.0     NaN
# 163440   82042        Sandra Anne Morgan (-Beavis)   F  14.0   167.0    67.0
# 147676   74100            Bernard Robert Malivoire   M  14.0     NaN     NaN
# 240012  120276                     Gunther Tiersch   M  14.0   160.0    45.0
#
#                  Team  NOC        Games  Year  Season         City  \
# ...

# %%
# Definiendo un segundo parametro para el ordenamiento y pasando el parametro de Ascending.
olympics_gold.sort_values(by= ['Age', 'NOC'], ascending = False).head(10)
# Out:
#             ID                                     Name Sex   Age  Height  \
# 105199   53238                          Charles Jacobus   M  64.0     NaN
# 233390  117046                        Oscar Gomer Swahn   M  64.0     NaN
# 190952   95906  Lida Peyton "Eliza" Pollock (McMillen-)   F  63.0     NaN
# 226374  113773             Galen Carter "G. C." Spencer   M  63.0   165.0
# 261102  130662                  Robert W. Williams, Jr.   M  63.0     NaN
# 104003   52626                     Isaac Lazarus Israls   M  63.0     NaN
# 261675  130936                            Walter Winans   M  60.0     NaN
# 233386  117046                        Oscar Gomer Swahn   M  60.0     NaN
# 233387  117046                        Oscar Gomer Swahn   M  60.0     NaN
# 159298   79961                   Joshua Kearney Millner   M  60.0     NaN
#
#         Weight                Team  NOC        Games  Year  Season       City  \
# ...

# %%
# Definiendo el ordenamiento por cada columna.
olympics_gold.sort_values(by= ['Age', 'NOC'], ascending = [True, False]).head(10)
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 52010    26731   Donna Elizabeth de Varona (-Pinto)   F  13.0   168.0    61.0
# 78544    39866         Marjorie Gestring (-Redlick)   F  13.0     NaN     NaN
# 200704  100797        Aileen Muriel Riggin (-Soule)   F  13.0   142.0     NaN
# 27207    14142                        Hans Bourquin   M  13.0     NaN     NaN
# 119277   60384                           Kim Yun-Mi   F  13.0   160.0    48.0
# 268602  134381                          Klaus Zerta   M  13.0   165.0    48.0
# 73581    37398                           Fu Mingxia   F  13.0   160.0    48.0
# 16849     9034            Amanda Ray Beard (-Brown)   F  14.0   173.0    59.0
# 150298   75395                 Barbara Ann Marshall   F  14.0   175.0    59.0
# 160920   80754  Dominique Helena Moceanu (-Canales)   F  14.0   139.0    34.0
#
#                  Team  NOC        Games  Year  Season         City  \
# ...

# %% [markdown]
# ## Eventos duplicados.

# %%
# Generando dataset de consulta deportistas peruanos que ganaron medallas de plata.
olympics_PE = olympics.query('NOC == "PER" & Medal == "Silver"')
olympics_PE
# Out:
#             ID                                             Name Sex   Age  \
# 27728    14388                             Francisco Boza Dibos   M  19.0
# 37847    19448                     Luisa Haydee Cervera Cevedon   F  24.0
# 51127    26272                           Alejandra de la Guerra   F  20.0
# 66098    33819                            Denisse Fajardo Garca   F  24.0
# 75122    38118                                  Miriam Gallardo   F  20.0
# 76249    38692                         Rosa Gisella Garca Rivas   F  24.0
# 79227    40231                       Juan Jorge Giha Yarur, Jr.   M  37.0
# 94622    47883                             Sonia Isabel Heredia   F  24.0
# 98804    50004                          Katherine "Kathy" Horny   F  18.0
# 147339   73946                         Natalia Mara Mlaga Dibos   F  24.0
# 185611   93317  Gabriela Lourdes "Gaby" Prez del Solar Cuculiza   F  20.0
# 234999  117844                   Cecilia Roxana Tait Villacorta   F  26.0
# ...

# %%
# Eliminando valores duplicados.
olympics_PE.drop_duplicates()
# Out:
#             ID                                             Name Sex   Age  \
# 27728    14388                             Francisco Boza Dibos   M  19.0
# 37847    19448                     Luisa Haydee Cervera Cevedon   F  24.0
# 51127    26272                           Alejandra de la Guerra   F  20.0
# 66098    33819                            Denisse Fajardo Garca   F  24.0
# 75122    38118                                  Miriam Gallardo   F  20.0
# 76249    38692                         Rosa Gisella Garca Rivas   F  24.0
# 79227    40231                       Juan Jorge Giha Yarur, Jr.   M  37.0
# 94622    47883                             Sonia Isabel Heredia   F  24.0
# 98804    50004                          Katherine "Kathy" Horny   F  18.0
# 147339   73946                         Natalia Mara Mlaga Dibos   F  24.0
# 185611   93317  Gabriela Lourdes "Gaby" Prez del Solar Cuculiza   F  20.0
# 234999  117844                   Cecilia Roxana Tait Villacorta   F  26.0
# ...

# %%
# Eliminando valores nulos con dropna.
olympics_medals =  olympics.dropna(subset = 'Medal')

# %%
# Validando valores nulos en la columna Medal.
olympics_medals.isnull().sum()
# Out:
# ID           0
# Name         0
# Sex          0
# Age        732
# Height    8711
# Weight    9327
# Team         0
# NOC          0
# Games        0
# Year         0
# Season       0
# City         0
# Sport        0
# Event        0
# Medal        0
# dtype: int64

# %%
# Eliminando valores nulos con dropna.
olympics_dropna_all =  olympics.dropna(how='all')

# %%
olympics_dropna_all.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
medals = olympics.dropna(subset='Medal')

# %%
medals.head()
# Out:
#     ID                      Name Sex   Age  Height  Weight            Team  \
# 3    4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 37  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 38  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0         Finland
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
#
#     NOC        Games  Year  Season       City       Sport  \
# 3   DEN  1900 Summer  1900  Summer      Paris  Tug-Of-War
# 37  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 38  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 40  FIN  2014 Winter  2014  Winter      Sochi  Ice Hockey
# 41  FIN  1948 Summer  1948  Summer     London  Gymnastics
#
#                                      Event   Medal
# 3              Tug-Of-War Men's Tug-Of-War    Gold
# 37  Swimming Men's 200 metres Breaststroke  Bronze
# ...

# %%
medals.shape
# Out:
# (39783, 15)

# %%
# Eliminando atletas duplicados para un evento en particular.
medals = medals.drop_duplicates(subset=['Games', 'Event'])
medals.shape
# Out:
# (6168, 15)

# %%
# Creando dataframe de un grupo head()
medals_subset = medals.head()

# %%
# Agrupando datos para  obtener la cantidad de medallas.
medals_subset.groupby('NOC').count()
# Out:
#      ID  Name  Sex  Age  Height  Weight  Team  Games  Year  Season  City  \
# NOC
# DEN   1     1    1    1       0       0     1      1     1       1     1
# FIN   4     4    4    4       2       2     4      4     4       4     4
#
#      Sport  Event  Medal
# NOC
# DEN      1      1      1
# FIN      4      4      4

# %%
# Seleccionando la columna deseada.
medals_subset.groupby('NOC').count()['Medal']
# Out:
# NOC
# DEN    1
# FIN    4
# Name: Medal, dtype: int64

# %%
# Ordenando por medallas acorde con la cantidad de medallas ganadas por pais.
medals_count = medals.get(['NOC', 'Medal']).groupby('NOC', as_index=False).count()
medals_count.head()
# Out:
#    NOC  Medal
# 0  AHO      1
# 1  ALG      4
# 2  ANZ      8
# 3  ARG     36
# 4  ARM      9

# %%
# 85 Ordenando con GroupBy.
medals_count.sort_values(by= 'Medal', ascending=False).head()
# Out:
#      NOC  Medal
# 114  USA    988
# 112  URS    371
# 33   FRA    354
# 38   GER    334
# 35   GBR    326

# %%
# 86. realizando filtros bor deportes.
olympics_gb = olympics.get(['Sport', 'Age', 'Height','Weight'])
olympics_gb.head()
# Out:
#            Sport   Age  Height  Weight
# 0     Basketball  24.0   180.0    80.0
# 1           Judo  23.0   170.0    60.0
# 2       Football  24.0     NaN     NaN
# 3     Tug-Of-War  34.0     NaN     NaN
# 4  Speed Skating  21.0   185.0    82.0

# %%
# 86. realizando filtros bor deportes.
olympics_gb = olympics_gb[olympics_gb['Sport'].isin(['Basketball','Football'])]
olympics_gb.head()
# Out:
#           Sport   Age  Height  Weight
# 0    Basketball  24.0   180.0    80.0
# 2      Football  24.0     NaN     NaN
# 105    Football  23.0   182.0    64.0
# 116    Football  28.0     NaN     NaN
# 157    Football  26.0   175.0    72.0

# %%
# # 86. realizando filtros bor deportes. Agrupando dataframe por la columna Deporte.
olympics_gb.groupby('Sport').count()
# Out:
#              Age  Height  Weight
# Sport
# Basketball  4350    3881    3678
# Football    6370    4647    4533

# %%
# Realizando agrupaciones con opciones de agregacion para cada campo.
olympics_gb.groupby('Sport').agg({'Age': 'mean', 'Height': ['min', 'max']})
# Out:
#                   Age Height
#                  mean    min    max
# Sport
# Basketball  25.324598  161.0  226.0
# Football    23.693250  140.0  200.0

# %%
# 86. realizando filtros bor deportes. 
# Realizando agrupaciones con opciones de agregacion para cada campo con la libreria numpy np.
olympics_gb.groupby('Sport').agg({'Age': np.mean, 'Height': [np.min, np.max]})
# Out:
#                   Age Height
#                  mean    min    max
# Sport
# Basketball  25.324598  161.0  226.0
# Football    23.693250  140.0  200.0

# %%
# 87. Pivot tables.
# Contar los paises con el mayor numero de medallas.
medals_count = medals.get(['NOC', 'Medal']).groupby('NOC', as_index=False).count()
medals_count.head()
# Out:
#    NOC  Medal
# 0  AHO      1
# 1  ALG      4
# 2  ANZ      8
# 3  ARG     36
# 4  ARM      9

# %%
# 87. Pivot tables.
# Contando por grupo 
medals_count.sort_values(by='Medal', ascending=False).head(10)
# Out:
#      NOC  Medal
# 114  USA    988
# 112  URS    371
# 33   FRA    354
# 38   GER    334
# 35   GBR    326
# 54   ITA    290
# 97   SWE    240
# 90   RUS    192
# 78   NOR    190
# 16   CAN    162

# %%
# 87. Pivot tables.
# Cuentas de medallas por tipo (Oro, plata, bronce) y Pais.
medals.query('Medal == "Gold"')\
    .get(['NOC', 'Medal'])\
    .groupby('NOC', as_index=False)\
    .count()\
    .sort_values(by = 'Medal', ascending = False)\
    .head(10)
# Out:
#     NOC  Medal
# 79  USA    412
# 77  URS    151
# 26  FRA    110
# 39  ITA    104
# 31  GER    103
# 28  GBR     93
# 53  NOR     81
# 66  SWE     66
# 61  RUS     60
# 33  HUN     54

# %%
# 87. Pivot tables.
# Cuentas de medallas por tipo (Oro, plata, bronce) y Pais.
medals.get(['NOC', 'Medal', 'Event'])\
    .groupby(['NOC', 'Medal'], as_index=False)\
    .count()
# Out:
#      NOC   Medal  Event
# 0    AHO  Silver      1
# 1    ALG  Bronze      2
# 2    ALG    Gold      1
# 3    ALG  Silver      1
# 4    ANZ  Bronze      3
# ..   ...     ...    ...
# 281  YUG  Bronze      7
# 282  YUG    Gold     11
# 283  YUG  Silver      8
# 284  ZIM    Gold      1
# 285  ZIM  Silver      1
#
# [286 rows x 3 columns]

# %%
# Realizando  busqueda con el comando pivot_table filtrando los valores NAN por ceros '0'.
medals_pivot = medals.get(['NOC', 'Medal', 'Event']).pivot_table(index = 'NOC', columns = 'Medal', aggfunc = 'count', fill_value =0)
medals_pivot
# Out:
#        Event
# Medal Bronze Gold Silver
# NOC
# AHO        0    0      1
# ALG        2    1      1
# ANZ        3    2      3
# ARG       13   10     13
# ARM        5    1      3
# ..       ...  ...    ...
# VEN        5    0      0
# VIE        0    1      2
# WIF        1    0      0
# YUG        7   11      8
# ZIM        0    1      1
#
# [121 rows x 3 columns]

# %%
medals_pivot.columns
# Out:
# MultiIndex([('Event', 'Bronze'),
#             ('Event',   'Gold'),
#             ('Event', 'Silver')],
#            names=[None, 'Medal'])

# %%
# 87. Pivot tables.
# Remplazando los valores de columnas con pivot table.
medals_pivot.columns = ['Bronze', 'Gold', 'Silver']

# %%
# 87. Pivot tables.
# Consultando contenido.
medals_pivot
# Out:
#      Bronze  Gold  Silver
# NOC
# AHO       0     0       1
# ALG       2     1       1
# ANZ       3     2       3
# ARG      13    10      13
# ARM       5     1       3
# ..      ...   ...     ...
# VEN       5     0       0
# VIE       0     1       2
# WIF       1     0       0
# YUG       7    11       8
# ZIM       0     1       1
#
# [121 rows x 3 columns]

# %%
# 87. Pivot tables.
# Cambiando el orden de las columnas.
medals_pivot = medals_pivot[['Gold', 'Silver', 'Bronze']]
medals_pivot
# Out:
#      Gold  Silver  Bronze
# NOC
# AHO     0       1       0
# ALG     1       1       2
# ANZ     2       3       3
# ARG    10      13      13
# ARM     1       3       5
# ..    ...     ...     ...
# VEN     0       0       5
# VIE     1       2       0
# WIF     0       0       1
# YUG    11       8       7
# ZIM     1       1       0
#
# [121 rows x 3 columns]

# %%
# 87. Pivot tables.
# Ordenando por una columna de mayor a menor.
medals_pivot.sort_values(by=['Gold'], ascending = False)
# Out:
#      Gold  Silver  Bronze
# NOC
# USA   412     304     272
# URS   151     117     103
# FRA   110     106     138
# ITA   104      89      97
# GER   103     121     110
# ..    ...     ...     ...
# MKD     0       0       1
# NIG     0       1       0
# PER     0       3       0
# PHI     0       1       0
# KGZ     0       1       0
#
# [121 rows x 3 columns]

# %%
# 88. Pivot tables - margenes.
# filtrando por campos.
medals = medals.get(['NOC', 'Medal', 'Event'])
medals.head()
# Out:
#     NOC   Medal                                   Event
# 3   DEN    Gold             Tug-Of-War Men's Tug-Of-War
# 37  FIN  Bronze  Swimming Men's 200 metres Breaststroke
# 38  FIN  Bronze  Swimming Men's 400 metres Breaststroke
# 40  FIN  Bronze             Ice Hockey Men's Ice Hockey
# 41  FIN  Bronze  Gymnastics Men's Individual All-Around

# %%
# 88. Pivot tables - margenes.
# Realizando consulta con meals pivotando con la columna NOC.
medals.pivot_table(index = 'NOC', columns = 'Medal', aggfunc = 'count', fill_value = 0, margins = True, margins_name = 'Total')
# Out:
#        Event
# Medal Bronze  Gold Silver Total
# NOC
# AHO        0     0      1     1
# ALG        2     1      1     4
# ANZ        3     2      3     8
# ARG       13    10     13    36
# ARM        5     1      3     9
# ...      ...   ...    ...   ...
# VIE        0     1      2     3
# WIF        1     0      0     1
# YUG        7    11      8    26
# ZIM        0     1      1     2
# Total   2110  2049   2009  6168
#
# [122 rows x 4 columns]

# %%
# 88. Pivot tables - margenes.
# Realizando consulta con meals pivotando con la columna NOC.
medals_pivot = medals.pivot_table(index = 'NOC', columns = 'Medal', aggfunc = 'count', fill_value = 0)
medals_pivot
# Out:
#        Event
# Medal Bronze Gold Silver
# NOC
# AHO        0    0      1
# ALG        2    1      1
# ANZ        3    2      3
# ARG       13   10     13
# ARM        5    1      3
# ..       ...  ...    ...
# VEN        5    0      0
# VIE        0    1      2
# WIF        1    0      0
# YUG        7   11      8
# ZIM        0    1      1
#
# [121 rows x 3 columns]

# %%
# 88. Pivot tables - margenes.
# Agregando columna de totales al dataframe medals_pivot.
medals_pivot['Total'] = medals_pivot.sum(axis = 1)
medals_pivot
# Out:
#        Event             Total
# Medal Bronze Gold Silver
# NOC
# AHO        0    0      1     1
# ALG        2    1      1     4
# ANZ        3    2      3     8
# ARG       13   10     13    36
# ARM        5    1      3     9
# ..       ...  ...    ...   ...
# VEN        5    0      0     5
# VIE        0    1      2     3
# WIF        1    0      0     1
# YUG        7   11      8    26
# ZIM        0    1      1     2
#
# [121 rows x 4 columns]

# %%
# 89. Pivot tables - Meelt.
# Realizando consulta con meals pivotando con la columna NOC.
medals_pivot = medals.pivot_table(index = 'NOC', columns = 'Medal', aggfunc = 'count', fill_value = 0)
medals_pivot.columns = ['Bronze', 'Gold', 'Silver']
medals_pivot
# Out:
#      Bronze  Gold  Silver
# NOC
# AHO       0     0       1
# ALG       2     1       1
# ANZ       3     2       3
# ARG      13    10      13
# ARM       5     1       3
# ..      ...   ...     ...
# VEN       5     0       0
# VIE       0     1       2
# WIF       1     0       0
# YUG       7    11       8
# ZIM       0     1       1
#
# [121 rows x 3 columns]

# %%
# 89. Pivot tables - Meelt.
# Reseteando el indice de columnas.
medals_pivot = medals_pivot.reset_index()
medals_pivot
# Out:
#      NOC  Bronze  Gold  Silver
# 0    AHO       0     0       1
# 1    ALG       2     1       1
# 2    ANZ       3     2       3
# 3    ARG      13    10      13
# 4    ARM       5     1       3
# ..   ...     ...   ...     ...
# 116  VEN       5     0       0
# 117  VIE       0     1       2
# 118  WIF       1     0       0
# 119  YUG       7    11       8
# 120  ZIM       0     1       1
#
# [121 rows x 4 columns]

# %%
# 89. Pivot tables - Meelt.
# Realizando consulta con meals pivotando con la columna NOC.
medals_melt = medals_pivot.melt(id_vars = 'NOC', value_vars = ['Bronze', 'Gold', 'Silver'], var_name = 'Medal', value_name = 'Count')
medals_melt
# Out:
#      NOC   Medal  Count
# 0    AHO  Bronze      0
# 1    ALG  Bronze      2
# 2    ANZ  Bronze      3
# 3    ARG  Bronze     13
# 4    ARM  Bronze      5
# ..   ...     ...    ...
# 358  VEN  Silver      0
# 359  VIE  Silver      2
# 360  WIF  Silver      0
# 361  YUG  Silver      8
# 362  ZIM  Silver      1
#
# [363 rows x 3 columns]

# %%
# Realizando filtro con el pais argentina. agrupando las columnas con melt.
medals_melt.query('NOC == "ARG"')
# Out:
#      NOC   Medal  Count
# 3    ARG  Bronze     13
# 124  ARG    Gold     10
# 245  ARG  Silver     13

# %% [markdown]
# ### Ejercicio propuesto de manipulacion y exploracion de medallas en china
# - Que efectos deportivos que tuvieron las olimpiadas realizadas en china Beijing 2008

# %%
# 91 Ejercicio China Solucion.
# Dataframe Original.
olympics.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
# 91 Ejercicio China Solucion.
# Creando dataframe con los registros unicos de la federacion de china y temporada de verano.
olympics_china = olympics.query('NOC == "CHN" & Season == "Summer"')
olympics_china
# Out:
#             ID           Name Sex   Age  Height  Weight   Team  NOC  \
# 0            1      A Dijiang   M  24.0   180.0    80.0  China  CHN
# 1            2       A Lamusi   M  23.0   170.0    60.0  China  CHN
# 1072       602  Abudoureheman   M  22.0   182.0    75.0  China  CHN
# 2611      1463      Ai Linuer   M  25.0   160.0    62.0  China  CHN
# 2612      1464      Ai Yanhan   F  14.0   168.0    54.0  China  CHN
# ...        ...            ...  ..   ...     ...     ...    ...  ...
# 270443  135272     Zou Wenzhi   M   NaN     NaN     NaN  China  CHN
# 270444  135273     Zou Yuchen   M  20.0   203.0   107.0  China  CHN
# 270445  135274   Zou Zhenxian   M  28.0   184.0    72.0  China  CHN
# 270559  135318       Zu Lijun   M  26.0   188.0    87.0  China  CHN
# 270822  135445        Zuo Yue   M  21.0   192.0    88.0  China  CHN
#
#               Games  Year  Season            City       Sport  \
# 0       1992 Summer  1992  Summer       Barcelona  Basketball
# ...

# %%
# 91 Ejercicio China Solucion.
# Filtrar los valores por medalla que no tengan registros nulos.
medals_china = olympics_china.dropna(subset= ['Medal'])
medals_china.head()
# Out:
#           ID          Name Sex   Age  Height  Weight   Team  NOC        Games  \
# 6437    3611   An Zhongxin   F  23.0   170.0    65.0  China  CHN  1996 Summer
# 11690   6381        Ba Yan   F  21.0   183.0    78.0  China  CHN  1984 Summer
# 14077   7597  Bao Yingying   F  24.0   172.0    67.0  China  CHN  2008 Summer
# 21260  11223    Bi Wenjing   F  14.0   142.0    35.0  China  CHN  1996 Summer
# 33513  17282    Cai Huijue   F  16.0   174.0    63.0  China  CHN  1996 Summer
#
#        Year  Season         City       Sport  \
# 6437   1996  Summer      Atlanta    Softball
# 11690  1984  Summer  Los Angeles  Basketball
# 14077  2008  Summer      Beijing     Fencing
# 21260  1996  Summer      Atlanta  Gymnastics
# 33513  1996  Summer      Atlanta    Swimming
#
#                                               Event   Medal
# 6437                      Softball Women's Softball  Silver
# 11690                 Basketball Women's Basketball  Bronze
# ...

# %%
# 91 Ejercicio China Solucion.
# Eliminando registros duplicados de columnas especificas.
medals_china = medals_china.drop_duplicates(subset = ['Games', 'Event'])
medals_china.head()
# Out:
#           ID          Name Sex   Age  Height  Weight   Team  NOC        Games  \
# 6437    3611   An Zhongxin   F  23.0   170.0    65.0  China  CHN  1996 Summer
# 11690   6381        Ba Yan   F  21.0   183.0    78.0  China  CHN  1984 Summer
# 14077   7597  Bao Yingying   F  24.0   172.0    67.0  China  CHN  2008 Summer
# 21260  11223    Bi Wenjing   F  14.0   142.0    35.0  China  CHN  1996 Summer
# 33513  17282    Cai Huijue   F  16.0   174.0    63.0  China  CHN  1996 Summer
#
#        Year  Season         City       Sport  \
# 6437   1996  Summer      Atlanta    Softball
# 11690  1984  Summer  Los Angeles  Basketball
# 14077  2008  Summer      Beijing     Fencing
# 21260  1996  Summer      Atlanta  Gymnastics
# 33513  1996  Summer      Atlanta    Swimming
#
#                                               Event   Medal
# 6437                      Softball Women's Softball  Silver
# 11690                 Basketball Women's Basketball  Bronze
# ...

# %%
# 91 Ejercicio China Solucion.
# Validando la cantidad total de medallas por año, agrupando datos.
medals_count = medals_china.get(['Year', 'Medal', 'Event']).groupby(['Year', 'Medal'], as_index = False).count()
medals_count
# Out:
#     Year   Medal  Event
# 0   1984  Bronze      9
# 1   1984    Gold     11
# 2   1984  Silver      6
# 3   1988  Bronze     10
# 4   1988    Gold      5
# 5   1988  Silver      8
# 6   1992  Bronze     10
# 7   1992    Gold     15
# 8   1992  Silver     19
# 9   1996  Bronze     10
# 10  1996    Gold     15
# 11  1996  Silver     18
# 12  2000  Bronze      9
# 13  2000    Gold     23
# 14  2000  Silver     13
# 15  2004  Bronze     11
# 16  2004    Gold     28
# 17  2004  Silver     16
# 18  2008  Bronze     21
# 19  2008    Gold     46
# 20  2008  Silver     18
# 21  2012  Bronze     20
# 22  2012    Gold     31
# 23  2012  Silver     23
# 24  2016  Bronze     23
# 25  2016    Gold     24
# 26  2016  Silver     14

# %%
# 91 Ejercicio China Solucion.
# Comparando las medallas por años en modo grafico con seaborn.
sb.barplot(data = medals_count, x = 'Year', y = 'Event', ci = None)
# Out:
# C:\Users\Oscar\AppData\Local\Temp\ipykernel_15672\664435181.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sb.barplot(data = medals_count, x = 'Year', y = 'Event', ci = None)
# <Axes: xlabel='Year', ylabel='Event'>

# %%
# 91 Ejercicio China Solucion.
# Separando el grafico por medallas.
plt.figure(figsize = (20, 10))
sb.barplot(data = medals_count, x = 'Year', y = 'Event', ci = None, hue = 'Medal', hue_order = ['Gold', 'Silver', 'Bronze'])
# Out:
# C:\Users\Oscar\AppData\Local\Temp\ipykernel_15672\3257709126.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sb.barplot(data = medals_count, x = 'Year', y = 'Event', ci = None, hue = 'Medal', hue_order = ['Gold', 'Silver', 'Bronze'])
# <Axes: xlabel='Year', ylabel='Event'>

# %% [markdown]
# ### Ejercicio evaluacion de Mujeres que participaron en las olimpiadas de verano y la evolucion en cuanto a participacion.

# %%
olympics = pd.read_csv(path_input_datasets+'athlete_events.csv')
olympics = olympics.query('Season == "Summer"')
olympics.head(5)
# Out:
#     ID                                Name Sex   Age  Height  Weight  \
# 0    1                           A Dijiang   M  24.0   180.0    80.0
# 1    2                            A Lamusi   M  23.0   170.0    60.0
# 2    3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3    4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26   8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
#
#               Team  NOC        Games  Year  Season         City       Sport  \
# 0            China  CHN  1992 Summer  1992  Summer    Barcelona  Basketball
# 1            China  CHN  2012 Summer  2012  Summer       London        Judo
# 2          Denmark  DEN  1920 Summer  1920  Summer    Antwerpen    Football
# 3   Denmark/Sweden  DEN  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 26     Netherlands  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                            Event Medal
# 0    Basketball Men's Basketball   NaN
# ...

# %%
# 93 Ejercicio Mujeres Olimpiadas - Solucion.
# Validando valores nulos y duplicados en atletas femeninas.
olympics.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9189
# Height     51857
# Weight     53854
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     188464
# dtype: int64

# %%
# 93 Ejercicio Mujeres Olimpiadas - Solucion.
# Seleccionando campos para crear el dataframe.
olympics =olympics.get(['ID', 'Name', 'Sex', 'Games', 'Year', 'Season'])

# %%
# 93 Ejercicio Mujeres Olimpiadas - Solucion.
# Consultando valores duplicados por atleta.
olympics.query('Year == 2016')
# Out:
#             ID                           Name Sex        Games  Year  Season
# 80          22                  Andreea Aanei   F  2016 Summer  2016  Summer
# 139         51              Nstor Abad Sanjun   M  2016 Summer  2016  Summer
# 140         51              Nstor Abad Sanjun   M  2016 Summer  2016  Summer
# 141         51              Nstor Abad Sanjun   M  2016 Summer  2016  Summer
# 142         51              Nstor Abad Sanjun   M  2016 Summer  2016  Summer
# ...        ...                            ...  ..          ...   ...     ...
# 271024  135528                  Marc Zwiebler   M  2016 Summer  2016  Summer
# 271053  135547  Viktoriya Viktorovna Zyabkina   F  2016 Summer  2016  Summer
# 271054  135547  Viktoriya Viktorovna Zyabkina   F  2016 Summer  2016  Summer
# 271055  135547  Viktoriya Viktorovna Zyabkina   F  2016 Summer  2016  Summer
# 271110  135568         Olga Igorevna Zyuzkova   F  2016 Summer  2016  Summer
#
# [13688 rows x 6 columns]

# %%
# 93 Ejercicio Mujeres Olimpiadas - Solucion.
# Eliminando valores duplicados.
olympics = olympics.drop_duplicates(subset = ['Games', 'ID'])
olympics.head()
# Out:
#     ID                                Name Sex        Games  Year  Season
# 0    1                           A Dijiang   M  1992 Summer  1992  Summer
# 1    2                            A Lamusi   M  2012 Summer  2012  Summer
# 2    3                 Gunnar Nielsen Aaby   M  1920 Summer  1920  Summer
# 3    4                Edgar Lindenau Aabye   M  1900 Summer  1900  Summer
# 26   8  Cornelia "Cor" Aalten (-Strannood)   F  1932 Summer  1932  Summer

# %%
# 93 Ejercicio Mujeres Olimpiadas - Solucion.
# Consultando valores duplicados por atleta.
olympics.query('Year == 2016')
# Out:
#             ID                                   Name Sex        Games  Year  \
# 80          22                          Andreea Aanei   F  2016 Summer  2016
# 139         51                      Nstor Abad Sanjun   M  2016 Summer  2016
# 148         55                    Antonio Abadia Beci   M  2016 Summer  2016
# 158         62                      Giovanni Abagnale   M  2016 Summer  2016
# 161         65                      Patimat Abakarova   F  2016 Summer  2016
# ...        ...                                    ...  ..          ...   ...
# 270941  135489  Anastasiya Valeryevna Zuyeva-Fesikova   F  2016 Summer  2016
# 271019  135525                         Martin Zwicker   M  2016 Summer  2016
# 271024  135528                          Marc Zwiebler   M  2016 Summer  2016
# 271053  135547          Viktoriya Viktorovna Zyabkina   F  2016 Summer  2016
# 271110  135568                 Olga Igorevna Zyuzkova   F  2016 Summer  2016
#
#         Season
# 80      Summer
# ...

# %%
# 93 Ejercicio Mujeres Olimpiadas - Solucion.
olympics_pivot = olympics.get(['Year', 'Sex', 'Name']).pivot_table(index = 'Year', columns = 'Sex', aggfunc = 'count', fill_value = 0)
olympics_pivot.head()
# Out:
#      Name
# Sex     F     M
# Year
# 1896    0   176
# 1900   23  1201
# 1904    6   644
# 1906    6   835
# 1908   44  1980

# %%
# 93 Ejercicio Mujeres Olimpiadas - Solucion.
# cammbiando nombre de la columna
olympics_pivot.columns = ['F', 'M']
olympics_pivot.head()
# Out:
#        F     M
# Year
# 1896   0   176
# 1900  23  1201
# 1904   6   644
# 1906   6   835
# 1908  44  1980

# %%
# 93 Ejercicio Mujeres Olimpiadas - Solucion.
# Calculando el total, sumando el contenido en el eje de las columnas.
olympics_pivot['TOTAL'] = olympics_pivot.sum(axis = 1)
olympics_pivot.head()
# Out:
#        F     M  TOTAL
# Year
# 1896   0   176    176
# 1900  23  1201   1224
# 1904   6   644    650
# 1906   6   835    841
# 1908  44  1980   2024

# %%
# 93 Ejercicio Mujeres Olimpiadas - Solucion.
# Calculando el porcentaje de mujeres por olimpiadas.
olympics_pivot['% F'] = olympics_pivot['F'] / olympics_pivot['TOTAL']
olympics_pivot
# Out:
#          F     M  TOTAL       % F
# Year
# 1896     0   176    176  0.000000
# 1900    23  1201   1224  0.018791
# 1904     6   644    650  0.009231
# 1906     6   835    841  0.007134
# 1908    44  1980   2024  0.021739
# 1912    53  2356   2409  0.022001
# 1920    78  2598   2676  0.029148
# 1924   156  3100   3256  0.047912
# 1928   312  2935   3247  0.096089
# 1932   201  1721   1922  0.104579
# 1936   361  4123   4484  0.080508
# 1948   446  3956   4402  0.101318
# 1952   521  4411   4932  0.105637
# 1956   384  2963   3347  0.114730
# 1960   613  4739   5352  0.114537
# 1964   680  4457   5137  0.132373
# 1968   783  4775   5558  0.140878
# 1972  1060  6054   7114  0.149002
# 1976  1260  4813   6073  0.207476
# 1980  1123  4136   5259  0.213539
# 1984  1569  5229   6798  0.230803
# 1988  2203  6251   8454  0.260587
# 1992  2723  6663   9386  0.290113
# 1996  3517  6822  10339  0.340168
# 2000  4068  6579  10647  0.382079
# 2004  4300  6257  10557  0.407313
# ...

# %%
# 93 Ejercicio Mujeres Olimpiadas - Solucion.
# Graficando la progresion a lo largo del tiempo.
olympics_pivot = olympics_pivot.reset_index()
olympics_pivot.head()
# Out:
#    Year   F     M  TOTAL       % F
# 0  1896   0   176    176  0.000000
# 1  1900  23  1201   1224  0.018791
# 2  1904   6   644    650  0.009231
# 3  1906   6   835    841  0.007134
# 4  1908  44  1980   2024  0.021739

# %%
# 93 Ejercicio Mujeres Olimpiadas - Solucion.
# Graficando la progresion a lo largo del tiempo.
sb.lineplot(data = olympics_pivot, x = 'Year', y = '% F')
# Out:
# <Axes: xlabel='Year', ylabel='% F'>
