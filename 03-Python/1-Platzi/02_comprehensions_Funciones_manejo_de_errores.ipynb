# %%
# Importando el Zen de Python
# El Zen de Python es una colección de principios que influyen en el diseño del lenguaje Python
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# Estructura de datos llamadas Conjuntos.
#
# - Propiedades principales.
#   - Se pueden modificar.
#   - No tienen un orden especifico.
#   - No permite duplicados.

# %%
set_countries = {'col', 'mex', 'bol', 'col'}
print(set_countries)
print(type(set_countries))

set_numbers = {1, 2, 2, 443, 23}
print(set_numbers)
print(type(set_numbers))

set_types = {1, 'hola', False, 12.12}
print(set_types)
print(type(set_types))

set_from_string = set('hoola')
print(set_from_string)
print(type(set_from_string))

set_from_tuples = set(('abc', 'def', 'abc', 'ghi'))
print(set_from_tuples)
print(type(set_from_tuples))

numbers = [1,2,3,4,5,1,2,3]
numbers_set = set(numbers)
print(numbers_set)
print(type(numbers_set))
unique_numbers = list(numbers_set)
print(unique_numbers)
print(type(unique_numbers))
# Out:
# {'mex', 'bol', 'col'}
# <class 'set'>
# {1, 2, 443, 23}
# <class 'set'>
# {False, 1, 'hola', 12.12}
# <class 'set'>
# {'l', 'o', 'h', 'a'}
# <class 'set'>
# {'ghi', 'def', 'abc'}
# <class 'set'>
# {1, 2, 3, 4, 5}
# <class 'set'>
# [1, 2, 3, 4, 5]
# <class 'list'>

# %% [markdown]
# ## Clase 03 modificando conjuntos.
#
#  Modificando conjuntos: En esta sección veremos cómo modificar conjuntos usando los diferentes métodos disponibles:
#
#  - add() - Agregar elementos
#  - update() - Actualizar/agregar múltiples elementos
#  - remove() - Eliminar elementos específicos
#  - discard() - Eliminar elementos de forma segura
#  - clear() - Eliminar todos los elementos

# %%
suramerica = {'per', 'bol', 'ecu', 'bra', 'arg', 'chi', 'par', 'uru', 'ven', 'guy', 'sur', 'guf'}
print('Paises de Suramerica:', suramerica)
print('Total paises:', len(suramerica))
print('col' in suramerica)
# Out:
# Paises de Suramerica: {'arg', 'guy', 'ven', 'par', 'bol', 'ecu', 'sur', 'chi', 'bra', 'uru', 'per', 'guf'}
# Total paises: 12
# False

# %%
# Agregar elementos
suramerica.add('col')
print('Paises de Suramerica:', suramerica)
print('Total paises:', len(suramerica))
print('col' in suramerica)
# Out:
# Paises de Suramerica: {'arg', 'guy', 'ven', 'par', 'bol', 'ecu', 'col', 'sur', 'chi', 'bra', 'uru', 'per', 'guf'}
# Total paises: 13
# True

# %%
# Actualizar/agregar múltiples elementos
suramerica.update({'col', 'bra', 'ecu'})
print('Paises de Suramerica:', suramerica)
print('Total paises:', len(suramerica))
# Out:
# Paises de Suramerica: {'arg', 'guy', 'ven', 'par', 'bol', 'ecu', 'col', 'sur', 'chi', 'bra', 'uru', 'per', 'guf'}
# Total paises: 13

# %%
# Eliminar elementos específicos
suramerica.add('bra')
suramerica.remove('bra')
print('Paises de Suramerica:', suramerica)
print('Total paises:', len(suramerica))
print('bra' in suramerica)
# Out:
# Paises de Suramerica: {'arg', 'guy', 'ven', 'par', 'bol', 'ecu', 'sur', 'chi', 'uru', 'per', 'guf'}
# Total paises: 11
# False

# %%
# Eliminar elementos de forma segura
suramerica.discard('bra')
print('Paises de Suramerica:', suramerica)
print('Total paises:', len(suramerica))
print('bra' in suramerica)
# Out:
# Paises de Suramerica: {'arg', 'guy', 'ven', 'par', 'bol', 'ecu', 'sur', 'chi', 'uru', 'per', 'guf'}
# Total paises: 11
# False

# %%
# Eliminar todos los elementos
suramerica.clear()
print('Paises de Suramerica:', suramerica)
print('Total paises:', len(suramerica))
# Out:
# Paises de Suramerica: set()
# Total paises: 0

# %% [markdown]
# ### Operaciones de conjuntos
#
# Las operaciones de conjuntos incluyen:
#  - union (|): combina todos los elementos únicos de dos conjuntos
#  - intersection (&): obtiene elementos que están en ambos conjuntos
#  - difference (-): obtiene elementos que están en el primer conjunto pero no en el segundo
#  - symmetric_difference (^): obtiene elementos que están en uno u otro conjunto, pero no en ambos

# %%
# Union de conjuntos

# La unión de conjuntos combina todos los elementos únicos de dos o más conjuntos
# Se puede realizar con el operador | o el método union()

# Ejemplo de unión de conjuntos

# Definimos dos conjuntos
countries = {'col', 'mex', 'bol'}
countries2 = {'per', 'bra'}

# Realizamos la unión de los conjuntos
countries_union = countries.union(countries2)
print(countries_union)

# También podemos usar el operador | para realizar la unión
countries_union2 = countries | countries2
print(countries_union2)
# Out:
# {'bol', 'col', 'mex', 'bra', 'per'}
# {'bol', 'col', 'mex', 'bra', 'per'}

# %%
# Intersection de conjuntos

# La intersección obtiene los elementos que están presentes en ambos conjuntos
# Se puede realizar con el operador & o el método intersection()

# Definimos dos conjuntos
set_a = {'col', 'mex', 'bol', 'per'}  
set_b = {'per', 'bol', 'bra'}

# Realizamos la intersección usando el método intersection()
intersection_result = set_a.intersection(set_b)
print('Intersection usando método:', intersection_result)

# También podemos usar el operador & 
intersection_result2 = set_a & set_b
print('Intersection usando operador &:', intersection_result2)
# Out:
# Intersection usando método: {'bol', 'per'}
# Intersection usando operador &: {'bol', 'per'}

# %%
# Diferencia de conjuntos

# La diferencia obtiene los elementos que están en el primer conjunto pero no en el segundo
# Se puede realizar con el operador - o el método difference()

# Definimos dos conjuntos
set_a = {'col', 'mex', 'bol', 'per'}
set_b = {'per', 'bol', 'bra'}

# Realizamos la diferencia usando el método difference()
difference_result = set_a.difference(set_b)
print('Diferencia usando método:', difference_result)

# También podemos usar el operador -
difference_result2 = set_a - set_b 
print('Diferencia usando operador -:', difference_result2)
# Out:
# Diferencia usando método: {'mex', 'col'}
# Diferencia usando operador -: {'mex', 'col'}

# %%
# Diferencia simétrica de conjuntos

# La diferencia simétrica obtiene los elementos que están en uno u otro conjunto, pero no en ambos
# Se puede realizar con el operador ^ o el método symmetric_difference()

# Definimos dos conjuntos
set_a = {'col', 'mex', 'bol', 'per'}
set_b = {'per', 'bol', 'bra'}

# Realizamos la diferencia simétrica usando el método symmetric_difference()
symmetric_difference_result = set_a.symmetric_difference(set_b)
print('Diferencia simétrica usando método:', symmetric_difference_result)

# También podemos usar el operador ^
symmetric_difference_result2 = set_a ^ set_b
print('Diferencia simétrica usando operador ^:', symmetric_difference_result2)
# Out:
# Diferencia simétrica usando método: {'mex', 'col', 'bra'}
# Diferencia simétrica usando operador ^: {'mex', 'col', 'bra'}
